# %%
import pandas as pd
df = pd.read_csv('data/president_heights.csv')

# %%
df.head()
# Out:
#    order               name  height(cm)
# 0      1  George Washington         189
# 1      2         John Adams         170
# 2      3   Thomas Jefferson         189
# 3      4      James Madison         163
# 4      5       James Monroe         183

# %%
df.tail()
# Out:
#     order            name  height(cm)
# 39     42    Bill Clinton         188
# 40     43  George W. Bush         182
# 41     44    Barack Obama         185
# 42     45    Donald Trump         191
# 43     46    Joseph Biden         182

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order       44 non-null     int64
#  1   name        44 non-null     object
#  2   height(cm)  44 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#            order  height(cm)
# count  44.000000   44.000000
# mean   23.522727  180.045455
# std    13.729087    7.064337
# min     1.000000  163.000000
# 25%    11.750000  174.750000
# 50%    24.000000  182.000000
# 75%    35.250000  183.500000
# max    46.000000  193.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=44, step=1)

# %%
df.columns
# Out:
# Index(['order', 'name', 'height(cm)'], dtype='object')

# %%
df.columns = ['order', 'name', 'height']
df.columns
# Out:
# Index(['order', 'name', 'height'], dtype='object')

# %%
arr = df.values
arr
# Out:
# array([[1, 'George Washington', 189],
#        [2, 'John Adams', 170],
#        [3, 'Thomas Jefferson', 189],
#        [4, 'James Madison', 163],
#        [5, 'James Monroe', 183],
#        [6, 'John Quincy Adams', 171],
#        [7, 'Andrew Jackson', 185],
#        [8, 'Martin Van Buren', 168],
#        [9, 'William Henry Harrison', 173],
#        [10, 'John Tyler', 183],
#        [11, 'James K. Polk', 173],
#        [12, 'Zachary Taylor', 173],
#        [13, 'Millard Fillmore', 175],
#        [14, 'Franklin Pierce', 178],
#        [15, 'James Buchanan', 183],
#        [16, 'Abraham Lincoln', 193],
#        [17, 'Andrew Johnson', 178],
#        [18, 'Ulysses S. Grant', 173],
#        [19, 'Rutherford B. Hayes', 174],
#        [20, 'James A. Garfield', 183],
#        [21, 'Chester A. Arthur', 183],
#        [23, 'Benjamin Harrison', 168],
#        [25, 'William McKinley', 170],
#        [26, 'Theodore Roosevelt', 178],
#        [27, 'William Howard Taft', 182],
# ...

# %%
df.shape
# Out:
# (44, 3)

# %% [markdown]
# ```sql
# select 'order', 'name'
# from df
# where height > 180 and order >= 20
# order by height desc
# limit 5;
# ```

# %%
df.sort_values(['height'], ascending=False)
# Out:
#     order                    name  height
# 33     36       Lyndon B. Johnson     193
# 15     16         Abraham Lincoln     193
# 42     45            Donald Trump     191
# 0       1       George Washington     189
# 2       3        Thomas Jefferson     189
# 39     42            Bill Clinton     188
# 38     41       George H. W. Bush     188
# 29     32   Franklin D. Roosevelt     188
# 41     44            Barack Obama     185
# 37     40           Ronald Reagan     185
# 6       7          Andrew Jackson     185
# 4       5            James Monroe     183
# 32     35         John F. Kennedy     183
# 14     15          James Buchanan     183
# 19     20       James A. Garfield     183
# 20     21       Chester A. Arthur     183
# 26     29       Warren G. Harding     183
# 35     38             Gerald Ford     183
# 9      10              John Tyler     183
# 40     43          George W. Bush     182
# 43     46            Joseph Biden     182
# ...

# %%
# df['height'] > 180
where = df['height'] > 180
df[where]
# Out:
#     order                   name  height
# 0       1      George Washington     189
# 2       3       Thomas Jefferson     189
# 4       5           James Monroe     183
# 6       7         Andrew Jackson     185
# 9      10             John Tyler     183
# 14     15         James Buchanan     183
# 15     16        Abraham Lincoln     193
# 19     20      James A. Garfield     183
# 20     21      Chester A. Arthur     183
# 24     27    William Howard Taft     182
# 26     29      Warren G. Harding     183
# 28     31         Herbert Hoover     182
# 29     32  Franklin D. Roosevelt     188
# 32     35        John F. Kennedy     183
# 33     36      Lyndon B. Johnson     193
# 34     37          Richard Nixon     182
# 35     38            Gerald Ford     183
# 37     40          Ronald Reagan     185
# 38     41      George H. W. Bush     188
# 39     42           Bill Clinton     188
# 40     43         George W. Bush     182
# 41     44           Barack Obama     185
# ...

# %%
col_idx = 2
df.iloc[1:3, :col_idx] # arr[:, 4]
# Out:
#    order              name
# 1      2        John Adams
# 2      3  Thomas Jefferson

# %%
df.sort_index()
# Out:
#     order                    name  height
# 0       1       George Washington     189
# 1       2              John Adams     170
# 2       3        Thomas Jefferson     189
# 3       4           James Madison     163
# 4       5            James Monroe     183
# 5       6       John Quincy Adams     171
# 6       7          Andrew Jackson     185
# 7       8        Martin Van Buren     168
# 8       9  William Henry Harrison     173
# 9      10              John Tyler     183
# 10     11           James K. Polk     173
# 11     12          Zachary Taylor     173
# 12     13        Millard Fillmore     175
# 13     14         Franklin Pierce     178
# 14     15          James Buchanan     183
# 15     16         Abraham Lincoln     193
# 16     17          Andrew Johnson     178
# 17     18        Ulysses S. Grant     173
# 18     19     Rutherford B. Hayes     174
# 19     20       James A. Garfield     183
# 20     21       Chester A. Arthur     183
# ...

# %%
df.set_index(keys=['order']).sort_index()
# Out:
#                          name  height
# order
# 1           George Washington     189
# 2                  John Adams     170
# 3            Thomas Jefferson     189
# 4               James Madison     163
# 5                James Monroe     183
# 6           John Quincy Adams     171
# 7              Andrew Jackson     185
# 8            Martin Van Buren     168
# 9      William Henry Harrison     173
# 10                 John Tyler     183
# 11              James K. Polk     173
# 12             Zachary Taylor     173
# 13           Millard Fillmore     175
# 14            Franklin Pierce     178
# 15             James Buchanan     183
# 16            Abraham Lincoln     193
# 17             Andrew Johnson     178
# 18           Ulysses S. Grant     173
# 19        Rutherford B. Hayes     174
# 20          James A. Garfield     183
# 21          Chester A. Arthur     183
# 23          Benjamin Harrison     168
# 25           William McKinley     170
# ...

# %%
import numpy as np
arr = np.array([1, 2, 3])
arr / 10
# Out:
# array([0.1, 0.2, 0.3])

# %%
df['height'] / 10
# Out:
# 0     18.9
# 1     17.0
# 2     18.9
# 3     16.3
# 4     18.3
# 5     17.1
# 6     18.5
# 7     16.8
# 8     17.3
# 9     18.3
# 10    17.3
# 11    17.3
# 12    17.5
# 13    17.8
# 14    18.3
# 15    19.3
# 16    17.8
# 17    17.3
# 18    17.4
# 19    18.3
# 20    18.3
# 21    16.8
# 22    17.0
# 23    17.8
# 24    18.2
# 25    18.0
# 26    18.3
# 27    17.8
# 28    18.2
# 29    18.8
# 30    17.5
# 31    17.9
# 32    18.3
# 33    19.3
# 34    18.2
# 35    18.3
# 36    17.7
# 37    18.5
# 38    18.8
# 39    18.8
# 40    18.2
# 41    18.5
# 42    19.1
# 43    18.2
# Name: height, dtype: float64

# %%
pop = pd.read_csv('data/state-population.csv')
area = pd.read_csv('data/state-areas.csv')
abb = pd.read_csv('data/state-abbrevs.csv')

# %% [markdown]
# select
# from

# %%
area.columns = ['state', 'area']
area.columns
# Out:
# Index(['state', 'area'], dtype='object')

# %%
new_df = pd.merge(area, abb, how='left')
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   area (sq. mi)  52 non-null     int64
#  2   abbreviation   51 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %%
abb.shape, area.shape, pop.shape
# Out:
# ((51, 2), (52, 2), (2544, 4))

# %%
pop.columns = ['state', 'ages', 'year', 'pop']
pop.columns
# Out:
# Index(['state', 'ages', 'year', 'pop'], dtype='object')

# %%
pd.join(df1, df2)

# %% [markdown]
# p.135-missing value

# %%
import pandas as pd
df = pd.read_csv('data/president_heights2.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order       44 non-null     int64
#  1   name        44 non-null     object
#  2   height(cm)  41 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df.columns = ['order', 'name', 'height']

# %%
mask = df['height'].isna()
df[mask]
# Out:
#     order                 name  height
# 14     15       James Buchanan     NaN
# 23     26   Theodore Roosevelt     NaN
# 24     27  William Howard Taft     NaN

# %%
df['height'] = df['height'].fillna(df['order'].mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   order   44 non-null     int64
#  1   name    44 non-null     object
#  2   height  44 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df = df.drop(columns=['name'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   order   44 non-null     int64
#  1   height  44 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 836.0 bytes

# %% [markdown]
# p.161

# %%
import pandas as pd
df2 = pd.read_csv('data/president_heights.csv')

# %%
pd.concat([df, df2], axis=1).shape # 엥 이거 아닌데,,,
# Out:
# (44, 5)

# %% [markdown]
# p.184

# %%
import seaborn as sns

# %%
df = sns.load_dataset('planets')

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ```sql
# select method, mean(orbital_period), sum(mass)
# from df
# group by year, method
# ```

# %%
df.groupby(['year', 'method']).agg({
    'orbital_period' : 'mean',
    'mass': 'sum'
})
# Out:
#                                 orbital_period     mass
# year method
# 1989 Radial Velocity                 83.888000  11.6800
# 1992 Pulsar Timing                   45.901950   0.0000
# 1994 Pulsar Timing                   98.211400   0.0000
# 1995 Radial Velocity                  4.230785   0.4720
# 1996 Radial Velocity                335.961656   7.9176
# ...                                        ...      ...
# 2013 Transit                         45.729571   1.4700
#      Transit Timing Variations       22.339500   0.0000
# 2014 Radial Velocity               1326.098727   5.3400
#      Transit                         18.923712   0.0000
#      Transit Timing Variations             NaN   0.0000
#
# [69 rows x 2 columns]

# %%
df.groupby('method')['orbital_period'].mean() # 위의 코드와 같은 형태
# Out:
# method
# Astrometry                          631.180000
# Eclipse Timing Variations          4751.644444
# Imaging                          118247.737500
# Microlensing                       3153.571429
# Orbital Brightness Modulation         0.709307
# Pulsar Timing                      7343.021201
# Pulsation Timing Variations        1170.000000
# Radial Velocity                     823.354680
# Transit                              21.102073
# Transit Timing Variations            79.783500
# Name: orbital_period, dtype: float64

# %%
type(df.groupby(['year', 'method']))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df.groupby(['year', 'method']).filter(lambda x: print(type(x)))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
for g in df.groupby(['year', 'method']): # 위의 코드와 같은 방식
    print(type(g), type(g[0]), type(g[1]))
# Out:
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# p.197

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.pivot_table(index=['pclass'], columns=['sex'], values=['survived', 'fare'])
# Out:
#               fare             survived
# sex         female       male    female      male
# pclass
# 1       106.125798  67.226127  0.968085  0.368852
# 2        21.970121  19.741782  0.921053  0.157407
# 3        16.118810  12.661633  0.500000  0.135447

# %% [markdown]
# p.202

# %%
birth = pd.read_csv('data/births.csv')
birth.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
birth['decade'] = 10 * (birth['year'] // 10)
birth.columns
# Out:
# Index(['year', 'month', 'day', 'gender', 'births', 'decade'], dtype='object')

# %%
birth.pivot_table('births', index='decade', columns='gender', aggfunc='sum')
# Out:
# gender         F         M
# decade
# 1960     1753634   1846572
# 1970    16263075  17121550
# 1980    18310351  19243452
# 1990    19479454  20420553
# 2000    18229309  19106428

# %%
birth.pivot_table('births', index='year', columns='gender', aggfunc='sum')
# Out:
# gender        F        M
# year
# 1969    1753634  1846572
# 1970    1819164  1918636
# 1971    1736774  1826774
# 1972    1592347  1673888
# 1973    1533102  1613023
# 1974    1543005  1627626
# 1975    1535546  1618010
# 1976    1547613  1628863
# 1977    1623363  1708796
# 1978    1626324  1711976
# 1979    1705837  1793958
# 1980    1762459  1855522
# 1981    1772037  1863478
# 1982    1797239  1888218
# 1983    1775299  1867522
# 1984    1791802  1881766
# 1985    1834774  1930290
# 1986    1833708  1926987
# 1987    1860111  1953105
# 1988    1909210  2004583
# 1989    1973712  2071981
# 1990    2030966  2131951
# 1991    2011601  2103741
# 1992    1985118  2084310
# 1993    1953456  2051067
# 1994    1932234  2024691
# 1995    1904871  1998141
# 1996    1902664  1992210
# 1997    1896928  1987401
# 1998    1927106  2018086
# 1999    1934510  2028955
# 2000    1984255  2079568
# 2001    1970770  2060761
# 2002    1966519  2060857
# 2003    1999387  2096705
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

sns.set_theme(style="ticks", palette="pastel")
birth.pivot_table('births', index='year', columns='gender', aggfunc='sum').plot()
plt.ylabel('total births per year')
# Out:
# Text(0, 0.5, 'total births per year')

# %%
births = pd.read_csv('data/births2.csv')
births.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15547 entries, 0 to 15546
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    15547 non-null  int64
#  1   month   15547 non-null  int64
#  2   day     15067 non-null  float64
#  3   gender  15547 non-null  object
#  4   births  15547 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 607.4+ KB

# %%
births[births['day'].isna()]
# Out:
#        year  month  day gender  births
# 15067  1989      1  NaN      F  156749
# 15068  1989      1  NaN      M  164052
# 15069  1989      2  NaN      F  146710
# 15070  1989      2  NaN      M  154047
# 15071  1989      3  NaN      F  165889
# ...     ...    ...  ...    ...     ...
# 15542  2008     10  NaN      M  183219
# 15543  2008     11  NaN      F  158939
# 15544  2008     11  NaN      M  165468
# 15545  2008     12  NaN      F  173215
# 15546  2008     12  NaN      M  181235
#
# [480 rows x 5 columns]

# %%
births['day'] = births['day'].fillna(1)
births[births['day'].isna()]
# Out:
# Empty DataFrame
# Columns: [year, month, day, gender, births]
# Index: []

# %% [markdown]
# nan값을 1로 넣고, 날짜데이터를 포맷팅해야함

# %%
births['date'] = pd.to_datetime(dates, format='%Y%m%d') # 왜 안돼 ㅅㅂ
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 births['date'] = pd.to_datetime(dates, format='%Y%m%d')
#
# File c:\venvs\DS_Coding\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# File c:\venvs\DS_Coding\Lib\site-packages\pandas\core\tools\datetimes.py:249, in _maybe_cache(arg, format, cache, convert_listlike)
#     247 unique_dates = unique(arg)
#     248 if len(unique_dates) < len(arg):
# --> 249     cache_dates = convert_listlike(unique_dates, format)
# ...

# %%
import datetime as dt

dt.datetime(2025, 12, 4)
# Out:
# datetime.datetime(2025, 12, 4, 0, 0)

# %% [markdown]
# p.223

# %%
time_idx = pd.DatetimeIndex(['2025-12-01', '2025-12-02', '2025-12-03'])

# %%
p = pd.Series([1, 2, 3], index=time_idx)
p['2025-12':'2025-12']
# Out:
# 2025-12-01    1
# 2025-12-02    2
# 2025-12-03    3
# dtype: int64

# %% [markdown]
# p.229

# %%
# %pip install yfinance
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --------------------------- ------------ 2.1/3.0 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 10.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
# ...

# %%
import yfinance as yf
dat = yf.Ticker("TSLA")

# %%
type(dat)
# Out:
# yfinance.ticker.Ticker

# %%
df = yf.download(['TSLA'], period='5y')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20420\3567555419.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['TSLA'], period='5y')
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2020-12-04  199.679993  199.679993  195.166672  197.003326   88203900
# 2020-12-07  213.919998  216.263336  201.016663  201.639999  168929100
# 2020-12-08  216.626663  217.093338  206.166672  208.503326  192795000
# 2020-12-09  201.493332  218.106674  196.000000  217.896667  213873600
# 2020-12-10  209.023331  209.250000  188.779999  191.456665  201249600

# %%
df[['Close']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.loc['2020': '2021', ['Close']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.loc['2020-01': '2021-06', ['Close']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tesla = df['Close']
tesla
# Out:
# Ticker            TSLA
# Date
# 2020-12-04  199.679993
# 2020-12-07  213.919998
# 2020-12-08  216.626663
# 2020-12-09  201.493332
# 2020-12-10  209.023331
# ...                ...
# 2025-11-26  426.579987
# 2025-11-28  430.170013
# 2025-12-01  430.140015
# 2025-12-02  429.239990
# 2025-12-03  446.739990
#
# [1255 rows x 1 columns]

# %%
tesla = df['Close']
tesla.resample('W').mean().plot()
tesla.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fig, ax = plt.subplots(figsize=(10, 5))

tesla.resample('W').mean().plot(ax=ax, label='Weekly Mean')
tesla.plot(ax=ax, label='Daily', alpha=0.7)

ax.legend()
plt.show()

# %%
tesla = df['Close']
tesla.asfreq('D')
# Out:
# Ticker            TSLA
# Date
# 2020-12-04  199.679993
# 2020-12-05         NaN
# 2020-12-06         NaN
# 2020-12-07  213.919998
# 2020-12-08  216.626663
# ...                ...
# 2025-11-29         NaN
# 2025-11-30         NaN
# 2025-12-01  430.140015
# 2025-12-02  429.239990
# 2025-12-03  446.739990
#
# [1826 rows x 1 columns]

# %% [markdown]
# p.232

# %%
df2 = pd.read_csv('data/president_heights2.csv')
df2.head()
# Out:
#    order               name  height(cm)
# 0      1  George Washington       189.0
# 1      2         John Adams         NaN
# 2      3   Thomas Jefferson       170.0
# 3      4      James Madison       163.0
# 4      5       James Monroe       183.0

# %%
df2['height(cm)'].ffill() # 앞에걸로 채움, bfill - 뒤에걸로 채움
# Out:
# 0     189.0
# 1     189.0
# 2     170.0
# 3     163.0
# 4     183.0
# 5     171.0
# 6     185.0
# 7     168.0
# 8     173.0
# 9     183.0
# 10    173.0
# 11    173.0
# 12    175.0
# 13    178.0
# 14    178.0
# 15    193.0
# 16    178.0
# 17    173.0
# 18    174.0
# 19    183.0
# 20    183.0
# 21    168.0
# 22    170.0
# 23    170.0
# 24    170.0
# 25    180.0
# 26    183.0
# 27    178.0
# 28    182.0
# 29    188.0
# 30    175.0
# 31    179.0
# 32    183.0
# 33    193.0
# 34    182.0
# 35    183.0
# 36    177.0
# 37    185.0
# 38    188.0
# 39    188.0
# 40    182.0
# 41    185.0
# 42    191.0
# 43    182.0
# Name: height(cm), dtype: float64

# %%
tesla = df['Close']
tesla.asfreq('D', method='ffill')
# Out:
# Ticker            TSLA
# Date
# 2020-12-04  199.679993
# 2020-12-05  199.679993
# 2020-12-06  199.679993
# 2020-12-07  213.919998
# 2020-12-08  216.626663
# ...                ...
# 2025-11-29  430.170013
# 2025-11-30  430.170013
# 2025-12-01  430.140015
# 2025-12-02  429.239990
# 2025-12-03  446.739990
#
# [1826 rows x 1 columns]

# %%
tesla
# Out:
# Ticker            TSLA
# Date
# 2020-12-04  199.679993
# 2020-12-07  213.919998
# 2020-12-08  216.626663
# 2020-12-09  201.493332
# 2020-12-10  209.023331
# ...                ...
# 2025-11-26  426.579987
# 2025-11-28  430.170013
# 2025-12-01  430.140015
# 2025-12-02  429.239990
# 2025-12-03  446.739990
#
# [1255 rows x 1 columns]

# %%
tesla.shift(-365)
# Out:
# Ticker            TSLA
# Date
# 2020-12-04  236.603333
# 2020-12-07  236.473328
# 2020-12-08  221.300003
# 2020-12-09  224.966660
# 2020-12-10  209.386673
# ...                ...
# 2025-11-26         NaN
# 2025-11-28         NaN
# 2025-12-01         NaN
# 2025-12-02         NaN
# 2025-12-03         NaN
#
# [1255 rows x 1 columns]

# %%
ROI = 100 * (tesla.shift(-365) - tesla) / tesla
ROI.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tesla[1:6].mean()
# Out:
# Ticker
# TSLA    208.878665
# dtype: float64

# %%
tesla = df['Close']
tesla.rolling(5).mean()[:10] # 말아가지고 평균을 냇음(평균을 내든,, 더하든,,, 내 날짜를 포함함)
# Out:
# Ticker            TSLA
# Date
# 2020-12-04         NaN
# 2020-12-07         NaN
# 2020-12-08         NaN
# 2020-12-09         NaN
# 2020-12-10  208.148663
# 2020-12-11  208.878665
# 2020-12-14  208.750000
# 2020-12-15  207.641333
# 2020-12-16  208.860666
# 2020-12-17  210.782666

# %%
fig, ax = plt.subplots(figsize=(10, 5))

tesla.plot(ax=ax)
tesla.rolling(5).mean().plot(ax=ax)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# p.234

# %%
data = pd.read_csv('data/FremontBridge.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20420\3227980017.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv('data/FremontBridge.csv', index_col='Date', parse_dates=True)
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# 2019-11-01 04:00:00                   6.0                           5.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2019-11-01 00:00:00                           5.0
# 2019-11-01 01:00:00                           7.0
# ...

# %%
data.columns = ['Total', 'East', 'West']
data.dropna().describe() # dropna() - 결측값 행 제거
# Out:
#                Total           East           West
# count  147255.000000  147255.000000  147255.000000
# mean      110.341462      50.077763      60.263699
# std       140.422051      64.634038      87.252147
# min         0.000000       0.000000       0.000000
# 25%        14.000000       6.000000       7.000000
# 50%        60.000000      28.000000      30.000000
# 75%       145.000000      68.000000      74.000000
# max      1097.000000     698.000000     850.000000

# %%
data.plot()
plt.ylabel('Hourly Bicycle Count')
# Out:
# Text(0, 0.5, 'Hourly Bicycle Count')

# %%
weekly = data.resample('W').sum()
weekly.plot(style=['-', '-', '-'])
plt.ylabel('Weekly bicycle count')
# Out:
# Text(0, 0.5, 'Weekly bicycle count')
