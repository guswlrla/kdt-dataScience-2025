# %%
# p.252
# p .260
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1)

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x));

# %%
def graph(*args, scalex=True, **kwargs): # *args - 입력 데이터가 여러 형태라 유연하게 받기, **kwargs - 스타일의 모든걸 파라미터로 하나씩 받을 수 없어서 한번에 받음
    print(args)
    print(scalex)
    print(kwargs)

# %%
graph(1, 2, 3, x=5, y=7, c='red', ls='--')
# Out:
# (1, 2, 3)
# True
# {'x': 5, 'y': 7, 'c': 'red', 'ls': '--'}

# %%
plt.plot('sepal_length', data=df)
plt.axis('tight')

# %%
# p.269

# %%
# %pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
d = {'setosa': 0 , 'versicolor': 1, 'virginica': 2}
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.scatter(iris['sepal_length'], iris['sepal_width']);
plt.title('Iris Dataset')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
#p.282
plt.style.use('classic')
data = np.random.randn(1000)
plt.hist(data, bins=20)
# Out:
# (array([  5.,   4.,   8.,  22.,  33.,  51.,  91., 102., 115., 104., 137.,
#         100.,  76.,  66.,  38.,  29.,  15.,   2.,   0.,   2.]),
#  array([-2.95299304, -2.64829282, -2.34359259, -2.03889237, -1.73419215,
#         -1.42949193, -1.12479171, -0.82009149, -0.51539127, -0.21069105,
#          0.09400918,  0.3987094 ,  0.70340962,  1.00810984,  1.31281006,
#          1.61751028,  1.9222105 ,  2.22691072,  2.53161094,  2.83631117,
#          3.14101139]),
#  <BarContainer object of 20 artists>)

# %%
d1 = np.random.normal(0, 1, 1000)
d2 = np.random.normal(2, 10, 1000)
plt.hist(d1, density=True, alpha=0.3)
plt.hist(d2, density=True, alpha=0.3)
# Out:
# (array([0.00016493, 0.0021441 , 0.00808162, 0.01962678, 0.02902784,
#         0.0367796 , 0.03480042, 0.02127609, 0.00989586, 0.00313369]),
#  array([-32.28897602, -26.22583165, -20.16268728, -14.09954291,
#          -8.03639854,  -1.97325416,   4.08989021,  10.15303458,
#          16.21617895,  22.27932332,  28.34246769]),
#  <BarContainer object of 10 artists>)
